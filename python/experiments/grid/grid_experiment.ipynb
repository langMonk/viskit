# %%
import numpy as np
from matplotlib import pyplot as plt

NUMBER_OF_DATAPOINTS = 100

x = np.linspace(0, 1000, NUMBER_OF_DATAPOINTS)
y = np.linspace(0, 1000, NUMBER_OF_DATAPOINTS)

X, Y = np.meshgrid(x, y)

print(X)
print(Y)
# Out:
# [[   0.          10.1010101   20.2020202 ...  979.7979798  989.8989899
#   1000.       ]
#  [   0.          10.1010101   20.2020202 ...  979.7979798  989.8989899
#   1000.       ]
#  [   0.          10.1010101   20.2020202 ...  979.7979798  989.8989899
#   1000.       ]
#  ...
#  [   0.          10.1010101   20.2020202 ...  979.7979798  989.8989899
#   1000.       ]
#  [   0.          10.1010101   20.2020202 ...  979.7979798  989.8989899
#   1000.       ]
#  [   0.          10.1010101   20.2020202 ...  979.7979798  989.8989899
#   1000.       ]]
# [[   0.           0.           0.        ...    0.           0.
#      0.       ]
#  [  10.1010101   10.1010101   10.1010101 ...   10.1010101   10.1010101
#     10.1010101]
#  [  20.2020202   20.2020202   20.2020202 ...   20.2020202   20.2020202
#     20.2020202]
#  ...
#  [ 979.7979798  979.7979798  979.7979798 ...  979.7979798  979.7979798
#    979.7979798]
#  [ 989.8989899  989.8989899  989.8989899 ...  989.8989899  989.8989899
# ...

# %%
plt.figure(figsize=(16,16))
plt.scatter(X, Y)
